# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
from sklearn.svm import SVC
from sklearn import svm
from sklearn.model_selection import train_test_split

# %%
data=pd.read_csv("https://raw.githubusercontent.com/ezioauditore-tech/AI/main/datasets/Titanic/train.csv")
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.drop(['PassengerId','Name','Ticket'],axis=1,inplace=True)
data.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin Embarked
# 0         0       3    male  22.0      1      0   7.2500   NaN        S
# 1         1       1  female  38.0      1      0  71.2833   C85        C
# 2         1       3  female  26.0      0      0   7.9250   NaN        S
# 3         1       1  female  35.0      1      0  53.1000  C123        S
# 4         0       3    male  35.0      0      0   8.0500   NaN        S

# %%
data.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
data[data.Embarked.isnull()]
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch  Fare Cabin Embarked
# 61          1       1  female  38.0      0      0  80.0   B28      NaN
# 829         1       1  female  62.0      0      0  80.0   B28      NaN

# %%
data.drop(['Cabin'],axis=1,inplace=True)
data["Age"]=data["Age"].fillna(data["Age"].median())
data["Embarked"]=data["Embarked"].fillna("C")
data.Sex=data.Sex.replace(['male','female'],[0,1])
data.Embarked=data.Embarked.replace(['S','C','Q'],[0,1,2])
data
# Out:
#      Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0           0       3    0  22.0      1      0   7.2500         0
# 1           1       1    1  38.0      1      0  71.2833         1
# 2           1       3    1  26.0      0      0   7.9250         0
# 3           1       1    1  35.0      1      0  53.1000         0
# 4           0       3    0  35.0      0      0   8.0500         0
# ..        ...     ...  ...   ...    ...    ...      ...       ...
# 886         0       2    0  27.0      0      0  13.0000         0
# 887         1       1    1  19.0      0      0  30.0000         0
# 888         0       3    1  28.0      1      2  23.4500         0
# 889         1       1    0  26.0      0      0  30.0000         1
# 890         0       3    0  32.0      0      0   7.7500         2
#
# [891 rows x 8 columns]

# %%
data.dropna(inplace=True)
data
# Out:
#      Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0           0       3    0  22.0      1      0   7.2500         0
# 1           1       1    1  38.0      1      0  71.2833         1
# 2           1       3    1  26.0      0      0   7.9250         0
# 3           1       1    1  35.0      1      0  53.1000         0
# 4           0       3    0  35.0      0      0   8.0500         0
# ..        ...     ...  ...   ...    ...    ...      ...       ...
# 886         0       2    0  27.0      0      0  13.0000         0
# 887         1       1    1  19.0      0      0  30.0000         0
# 888         0       3    1  28.0      1      2  23.4500         0
# 889         1       1    0  26.0      0      0  30.0000         1
# 890         0       3    0  32.0      0      0   7.7500         2
#
# [891 rows x 8 columns]

# %%
test_data=pd.read_csv("https://raw.githubusercontent.com/ezioauditore-tech/AI/main/datasets/Titanic/test.csv")
test_data
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
test_data.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %% [markdown]
# test_data[test_data.Embarked.isnull().sum()]

# %%
test_data.drop(['Cabin'],axis=1,inplace=True)
test_data["Age"]=data["Age"].fillna(test_data["Age"].median())
test_data["Embarked"]=test_data["Embarked"].fillna("C")
test_data.Sex=data.Sex.replace(['male','female'],[0,1])
test_data.Embarked=data.Embarked.replace(['S','C','Q'],[0,1,2])
test_data
# Out:
#      PassengerId  Pclass                                          Name  Sex  \
# 0            892       3                              Kelly, Mr. James    0
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)    1
# 2            894       2                     Myles, Mr. Thomas Francis    1
# 3            895       3                              Wirz, Mr. Albert    1
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)    0
# ..           ...     ...                                           ...  ...
# 413         1305       3                            Spector, Mr. Woolf    0
# 414         1306       1                  Oliva y Ocana, Dona. Fermina    0
# 415         1307       3                  Saether, Mr. Simon Sivertsen    1
# 416         1308       3                           Ware, Mr. Frederick    1
# 417         1309       3                      Peter, Master. Michael J    1
#
# ...

# %%
test_data.dropna(inplace=True)

# %%
features=["Pclass","Sex","Age","SibSp","Parch","Embarked"]#independent variables

# %%
C=0.7
clf=svm.SVC(kernel='linear',C=C).fit(data[features],data["Survived"])

# %%
prediction=clf.predict(test_data[features])
